# %%
import pandas as pd

# %%
file = pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
file.shape
# Out:
# (1470, 35)

# %%
file.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
file
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
file.Age
# Out:
# 0       41
# 1       49
# 2       37
# 3       33
# 4       27
#         ..
# 1465    36
# 1466    39
# 1467    27
# 1468    49
# 1469    34
# Name: Age, Length: 1470, dtype: int64

# %%
file.iloc[0]
# Out:
# Age                                      41
# Attrition                               Yes
# BusinessTravel                Travel_Rarely
# DailyRate                              1102
# Department                            Sales
# DistanceFromHome                          1
# Education                                 2
# EducationField                Life Sciences
# EmployeeCount                             1
# EmployeeNumber                            1
# EnvironmentSatisfaction                   2
# Gender                               Female
# HourlyRate                               94
# JobInvolvement                            3
# JobLevel                                  2
# JobRole                     Sales Executive
# JobSatisfaction                           4
# MaritalStatus                        Single
# MonthlyIncome                          5993
# MonthlyRate                           19479
# NumCompaniesWorked                        8
# ...

# %%
file.iloc[:, 0]
# Out:
# 0       41
# 1       49
# 2       37
# 3       33
# 4       27
#         ..
# 1465    36
# 1466    39
# 1467    27
# 1468    49
# 1469    34
# Name: Age, Length: 1470, dtype: int64

# %%
file.iloc[:3, 0]
# Out:
# 0    41
# 1    49
# 2    37
# Name: Age, dtype: int64

# %%
file.iloc[1:3, 0]
# Out:
# 1    49
# 2    37
# Name: Age, dtype: int64

# %%
file.iloc[:2, 0]
# Out:
# 0    41
# 1    49
# Name: Age, dtype: int64

# %%
file.iloc[2:3, 0]
# Out:
# 2    37
# Name: Age, dtype: int64

# %%
file.iloc[[0, 1, 2,], 0]
# Out:
# 0    41
# 1    49
# 2    37
# Name: Age, dtype: int64

# %%
file.iloc[:-5]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1460   29        No      Travel_Rarely        468  Research & Development
# 1461   50       Yes      Travel_Rarely        410                   Sales
# 1462   39        No      Travel_Rarely        722                   Sales
# 1463   31        No         Non-Travel        325  Research & Development
# 1464   26        No      Travel_Rarely       1167                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
file.set_index("BusinessTravel")
# Out:
#                    Age Attrition  DailyRate              Department  \
# BusinessTravel
# Travel_Rarely       41       Yes       1102                   Sales
# Travel_Frequently   49        No        279  Research & Development
# Travel_Rarely       37       Yes       1373  Research & Development
# Travel_Frequently   33        No       1392  Research & Development
# Travel_Rarely       27        No        591  Research & Development
# ...                ...       ...        ...                     ...
# Travel_Frequently   36        No        884  Research & Development
# Travel_Rarely       39        No        613  Research & Development
# Travel_Rarely       27        No        155  Research & Development
# Travel_Frequently   49        No       1023                   Sales
# Travel_Rarely       34        No        628  Research & Development
#
#                    DistanceFromHome  Education EducationField  EmployeeCount  \
# BusinessTravel
# ...

# %%
file.loc[file.Department == 'Research & Development']
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1463   31        No         Non-Travel        325  Research & Development
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
file.loc[file.Department.isin(["Research & Development", "Sales"])]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
file.loc[file.BusinessTravel.isin(["Travel_Rarely", "Travel_Frequently"])]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
file.loc[file.TotalWorkingYears.notnull()]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
if file.isnull().sum().sum() == 0:
    print('CHECK: No missing data \n')
else:
    print('CHECK: Missing data found \n')
print(file.isnull().sum())
# Out:
# CHECK: No missing data
#
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# ...

# %%
file.rename(columns={'DailyRate': 'Rate'})
# Out:
#       Age Attrition     BusinessTravel  Rate              Department  \
# 0      41       Yes      Travel_Rarely  1102                   Sales
# 1      49        No  Travel_Frequently   279  Research & Development
# 2      37       Yes      Travel_Rarely  1373  Research & Development
# 3      33        No  Travel_Frequently  1392  Research & Development
# 4      27        No      Travel_Rarely   591  Research & Development
# ...   ...       ...                ...   ...                     ...
# 1465   36        No  Travel_Frequently   884  Research & Development
# 1466   39        No      Travel_Rarely   613  Research & Development
# 1467   27        No      Travel_Rarely   155  Research & Development
# 1468   49        No  Travel_Frequently  1023                   Sales
# 1469   34        No      Travel_Rarely   628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# ...
